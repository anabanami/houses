# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import numpy as np
import pandas as pd

# %%
houses_file = pd.read_csv('House_Prices_by_Small_Area_-_Sale_Year.csv').dropna(0)

# %%
houses_file
# Out:
#      Sale_Year                    Small_Area                   Type  \
# 0         2000                       Carlton        House/Townhouse
# 1         2000                       Carlton  Residential Apartment
# 2         2000                     Docklands  Residential Apartment
# 3         2000                East Melbourne        House/Townhouse
# 4         2000                East Melbourne  Residential Apartment
# ..         ...                           ...                    ...
# 340       2016                   South Yarra        House/Townhouse
# 341       2016                   South Yarra  Residential Apartment
# 342       2016                     Southbank  Residential Apartment
# 343       2016  West Melbourne (Residential)        House/Townhouse
# 344       2016  West Melbourne (Residential)  Residential Apartment
#
#      Median_Price  Transaction_Count
# 0        316250.0                116
# 1        220000.0                309
# ...

# %%
area = houses_file.Small_Area

# %%
year = houses_file.Sale_Year

# %%
median_price = houses_file.Median_Price

# %%
with plt.xkcd():
    plt.rcParams["figure.figsize"] = (36,10)
    plt.scatter(area, median_price, c=year, label='burb', s=400)
    plt.axis(ymin=0, ymax=0.6e7)
    plt.xlabel('burb')
    plt.ylabel('median price')
    plt.colorbar()
    plt.legend()
    plt.show()

# %%
"""
Pretty, specially because XKCD... but it is not super useful.
Another thing we could try visualise is how price changes as a function of time in a specific suburb.
"""

# %%
#Let's check if the burb Carlton
# is_carlton is a boolean variable with True or False in it
is_carlton = houses_file['Small_Area']=="Carlton"
#print(is_carlton.head())

carlton_properties = houses_file[is_carlton]
print("This is the size of the Carlton dataframe:",carlton_properties.shape)
#let's check our new carltonbased data
print(carlton_properties.head())
# Out:
# This is the size of the Carlton dataframe: (34, 5)
#     Sale_Year Small_Area                   Type  Median_Price  \
# 0        2000    Carlton        House/Townhouse      316250.0
# 1        2000    Carlton  Residential Apartment      220000.0
# 19       2001    Carlton        House/Townhouse      381000.0
# 20       2001    Carlton  Residential Apartment      273000.0
# 39       2002    Carlton        House/Townhouse      420000.0
#
#     Transaction_Count
# 0                 116
# 1                 309
# 19                113
# 20                366
# 39                108

# %%
burb_year = carlton_properties.Sale_Year

# %%
burb_price = carlton_properties.Median_Price

# %%
burb_type = carlton_properties.Type

# %%
with plt.xkcd():
    plt.rcParams["figure.figsize"] = (36,10)
    plt.scatter(burb_year, burb_price, s=400)
    plt.xlabel('year')
    plt.ylabel('median price')
    #plt.colorbar()
    #plt.legend()
    plt.show()
